-- %%
-- 1. Re-create Delta Table with FHIR Standard Column Names
CREATE OR REPLACE TABLE claimspan.bronze.measure_library (
    measureSource STRING,
    code STRING,
    system STRING,
    measureIdentifier STRING,
    measureTitle STRING,
    codeDisplay STRING,
    topicCategory STRING,
    subjectAdministrativeGender STRING,
    subjectAgeMin INT,
    subjectAgeMax INT,
    effectivePeriodStart DATE,
    effectivePeriodEnd DATE
)
USING DELTA;

-- 2. Insert Consolidated Measures Data

-- -----------------------------------------------------------------------------
-- MEASURE: Breast Cancer Screening (BCS-E)
-- -----------------------------------------------------------------------------
INSERT INTO claimspan.bronze.measure_library
SELECT 
    'hedis' AS measureSource,
    code,
    system,
    'BCS-E' AS measureIdentifier,
    'Breast Cancer Screening' AS measureTitle,
    codeDisplay,
    topicCategory,
    subjectAdministrativeGender,
    subjectAgeMin,
    subjectAgeMax,
    CAST(effectivePeriodStart AS DATE) AS effectivePeriodStart,
    CAST(effectivePeriodEnd AS DATE) AS effectivePeriodEnd
FROM (
    VALUES
        -- CPT
        ('77061', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('77062', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('77063', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('77065', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('77066', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('77067', 'CPT', 'MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),

        -- LOINC
        ('24604-1', 'LOINC', 'MG_BREAST_DIAGNOSTIC_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('24605-8', 'LOINC', 'MG_BREAST_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('24606-6', 'LOINC', 'MG_BREAST_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('24610-8', 'LOINC', 'MG_BREAST_LIMITED_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26175-0', 'LOINC', 'MG_BREAST_BILATERAL_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26176-8', 'LOINC', 'MG_BREAST_LEFT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26177-6', 'LOINC', 'MG_BREAST_RIGHT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26287-3', 'LOINC', 'MG_BREAST_BILATERAL_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26289-9', 'LOINC', 'MG_BREAST_LEFT_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26291-5', 'LOINC', 'MG_BREAST_RIGHT_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26346-7', 'LOINC', 'MG_BREAST_BILATERAL_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26347-5', 'LOINC', 'MG_BREAST_LEFT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26348-3', 'LOINC', 'MG_BREAST_RIGHT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26349-1', 'LOINC', 'MG_BREAST_BILATERAL_DIAG_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26350-9', 'LOINC', 'MG_BREAST_LEFT_DIAG_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('26351-7', 'LOINC', 'MG_BREAST_RIGHT_DIAG_LIMITED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36319-2', 'LOINC', 'MG_BREAST_4_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36625-2', 'LOINC', 'MG_BREAST_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36626-0', 'LOINC', 'MG_BREAST_BILATERAL_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36627-8', 'LOINC', 'MG_BREAST_LEFT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36642-7', 'LOINC', 'MG_BREAST_LEFT_2_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('36962-9', 'LOINC', 'MG_BREAST_AXILLARY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37005-6', 'LOINC', 'MG_BREAST_LEFT_MAGNIFICATION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37006-4', 'LOINC', 'MG_BREAST_BILATERAL_MLO', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37016-3', 'LOINC', 'MG_BREAST_BILATERAL_ROLLED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37017-1', 'LOINC', 'MG_BREAST_LEFT_ROLLED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37028-8', 'LOINC', 'MG_BREAST_TANGENTIAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37029-6', 'LOINC', 'MG_BREAST_BILATERAL_TANGENTIAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37030-4', 'LOINC', 'MG_BREAST_LEFT_TANGENTIAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37037-9', 'LOINC', 'MG_BREAST_TRUE_LATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37038-7', 'LOINC', 'MG_BREAST_BILATERAL_TRUE_LATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37052-8', 'LOINC', 'MG_BREAST_BILATERAL_XCCL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37053-6', 'LOINC', 'MG_BREAST_LEFT_XCCL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37539-4', 'LOINC', 'MG_BREAST_GRID_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37542-8', 'LOINC', 'MG_BREAST_MAGNIFICATION_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37543-6', 'LOINC', 'MG_BREAST_BILATERAL_MAGNIFICATION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37551-9', 'LOINC', 'MG_BREAST_SPOT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37552-7', 'LOINC', 'MG_BREAST_BILATERAL_SPOT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37553-5', 'LOINC', 'MG_BREAST_LEFT_SPOT_COMPRESSION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37554-3', 'LOINC', 'MG_BREAST_BILATERAL_MAG_SPOT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37768-9', 'LOINC', 'MG_BREAST_RIGHT_2_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37769-7', 'LOINC', 'MG_BREAST_RIGHT_MAG_SPOT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37770-5', 'LOINC', 'MG_BREAST_RIGHT_TANGENTIAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37771-3', 'LOINC', 'MG_BREAST_RIGHT_TRUE_LATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37772-1', 'LOINC', 'MG_BREAST_RIGHT_XCCL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37773-9', 'LOINC', 'MG_BREAST_RIGHT_MAGNIFICATION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37774-7', 'LOINC', 'MG_BREAST_RIGHT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('37775-4', 'LOINC', 'MG_BREAST_RIGHT_ROLLED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38070-9', 'LOINC', 'MG_BREAST_IMPLANT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38071-7', 'LOINC', 'MG_BREAST_BILATERAL_IMPLANT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38072-5', 'LOINC', 'MG_BREAST_LEFT_IMPLANT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38090-7', 'LOINC', 'MG_BREAST_BILATERAL_AIR_GAP', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38091-5', 'LOINC', 'MG_BREAST_LEFT_AIR_GAP', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38807-4', 'LOINC', 'MG_BREAST_RIGHT_SPOT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38820-7', 'LOINC', 'MG_BREAST_RIGHT_IMPLANT_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38854-6', 'LOINC', 'MG_BREAST_LEFT_MAG_SPOT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('38855-3', 'LOINC', 'MG_BREAST_LEFT_TRUE_LATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('39150-8', 'LOINC', 'FFD_MAMMOGRAM_POST_LOCALIZATION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('39152-4', 'LOINC', 'FFD_MAMMOGRAM_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('39153-2', 'LOINC', 'FFD_MAMMOGRAM_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('39154-0', 'LOINC', 'FFD_MAMMOGRAM_BILATERAL_DIAG', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('42168-5', 'LOINC', 'FFD_MAMMOGRAM_RIGHT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('42169-3', 'LOINC', 'FFD_MAMMOGRAM_LEFT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('42174-3', 'LOINC', 'FFD_MAMMOGRAM_BILATERAL_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('42415-0', 'LOINC', 'MG_BREAST_BILATERAL_POST_WIRE', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('42416-8', 'LOINC', 'MG_BREAST_LEFT_POST_WIRE', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46335-6', 'LOINC', 'MG_BREAST_BILATERAL_SINGLE_VIEW', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46336-4', 'LOINC', 'MG_BREAST_LEFT_SINGLE_VIEW', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46337-2', 'LOINC', 'MG_BREAST_RIGHT_SINGLE_VIEW', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46338-0', 'LOINC', 'MG_BREAST_UNILATERAL_SINGLE_VIEW', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46339-8', 'LOINC', 'MG_BREAST_UNILATERAL_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46342-2', 'LOINC', 'FFD_MAMMOGRAM_VIEWS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46350-5', 'LOINC', 'MG_BREAST_UNILATERAL_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46351-3', 'LOINC', 'MG_BREAST_BILATERAL_DISPLACEMENT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46354-7', 'LOINC', 'FFD_MAMMOGRAM_RIGHT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46355-4', 'LOINC', 'FFD_MAMMOGRAM_LEFT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46356-2', 'LOINC', 'MG_BREAST_UNILATERAL_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('46380-2', 'LOINC', 'MG_BREAST_UNILATERAL_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('48475-8', 'LOINC', 'MG_BREAST_BILATERAL_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('48492-3', 'LOINC', 'MG_BREAST_BILATERAL_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('69150-1', 'LOINC', 'MG_BREAST_LEFT_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('69251-7', 'LOINC', 'MG_BREAST_POST_WIRE_PLACEMENT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('69259-0', 'LOINC', 'MG_BREAST_RIGHT_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72137-3', 'LOINC', 'DBT_BREAST_RIGHT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72138-1', 'LOINC', 'DBT_BREAST_LEFT_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72139-9', 'LOINC', 'DBT_BREAST_BILATERAL_DIAGNOSTIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72140-7', 'LOINC', 'DBT_BREAST_RIGHT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72141-5', 'LOINC', 'DBT_BREAST_LEFT_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('72142-3', 'LOINC', 'DBT_BREAST_BILATERAL_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('86462-9', 'LOINC', 'DBT_BREAST_UNILATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('86463-7', 'LOINC', 'DBT_BREAST_BILATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91517-3', 'LOINC', 'DBT_BREAST_RIGHT_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91518-1', 'LOINC', 'DBT_BREAST_LEFT_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91519-9', 'LOINC', 'DBT_BREAST_BILATERAL_DIAG_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91520-7', 'LOINC', 'DBT_BREAST_RIGHT_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91521-5', 'LOINC', 'DBT_BREAST_LEFT_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('91522-3', 'LOINC', 'DBT_BREAST_BILATERAL_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('103885-0', 'LOINC', 'MG_BREAST_LEFT_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('103886-8', 'LOINC', 'MG_BREAST_RIGHT_SCREEN_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('103892-6', 'LOINC', 'DBT_BREAST_SCREENING', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('103893-4', 'LOINC', 'MG_BREAST_SCREENING_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('103894-2', 'LOINC', 'MG_BREAST_DIAGNOSTIC_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('76689-9', 'LOINC', 'SEX_ASSIGNED_AT_BIRTH', 'Demographics', 'ALL', 40, 74, '2024-10-01', '2026-12-31'),

        -- SNOMED CT
        ('12389009', 'SNOMED', 'XEROMAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('24623002', 'SNOMED', 'SCREENING_MAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('43204002', 'SNOMED', 'MAMMOGRAPHY_BILATERAL_BREASTS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('71651007', 'SNOMED', 'MAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('241055006', 'SNOMED', 'MAMMOGRAM_SYMPTOMATIC', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('241057003', 'SNOMED', 'MAMMOGRAM_CONED', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('241058008', 'SNOMED', 'MAMMOGRAM_MAGNIFICATION', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('258172002', 'SNOMED', 'STEREOTACTIC_MAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('439324009', 'SNOMED', 'MAMMOGRAM_COMPRESSION_VIEW', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('450566007', 'SNOMED', 'DIGITAL_BREAST_TOMOSYNTHESIS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('709657006', 'SNOMED', 'FLUOROSCOPY_OF_BREAST', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('723778004', 'SNOMED', 'DIGITAL_TOMOSYNTHESIS_RIGHT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('723779007', 'SNOMED', 'DIGITAL_TOMOSYNTHESIS_LEFT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('723780005', 'SNOMED', 'DIGITAL_TOMOSYNTHESIS_BILATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('726551006', 'SNOMED', 'SPECTRAL_MAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('833310007', 'SNOMED', 'DUAL_ENERGY_SPECTRAL_MAMMOGRAPHY', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('866234000', 'SNOMED', 'MAMMOGRAPHY_BREAST_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('866235004', 'SNOMED', 'MAMMOGRAPHY_BILATERAL_IMPLANTS', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('866236003', 'SNOMED', 'MAMMOGRAPHY_LEFT_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('866237007', 'SNOMED', 'MAMMOGRAPHY_RIGHT_IMPLANT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('384151000119104', 'SNOMED', 'SCREENING_MAMMOGRAPHY_BILATERAL', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('392521000119107', 'SNOMED', 'SCREENING_MAMMOGRAPHY_RIGHT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('392531000119105', 'SNOMED', 'SCREENING_MAMMOGRAPHY_LEFT', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('566571000119105', 'SNOMED', 'MAMMOGRAPHY_RIGHT_BREAST', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),
        ('572701000119102', 'SNOMED', 'MAMMOGRAPHY_LEFT_BREAST', 'Preventive Screening', 'F', 40, 74, '2024-10-01', '2026-12-31'),

        -- Exclusions (ICD10 / Modifiers)
        ('Z90.12', 'ICD10-CM', 'ABSENCE_OF_LEFT_BREAST', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('Z90.11', 'ICD10-CM', 'ABSENCE_OF_RIGHT_BREAST', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('Z90.13', 'ICD10-CM', 'HISTORY_OF_BILATERAL_MASTECTOMY', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('0HTV0ZZ', 'ICD10-PCS', 'BILATERAL_MASTECTOMY_PCS', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('0HTU0ZZ', 'ICD10-PCS', 'UNILATERAL_MASTECTOMY_LEFT_PCS', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('0HTT0ZZ', 'ICD10-PCS', 'UNILATERAL_MASTECTOMY_RIGHT_PCS', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('F64.1', 'ICD10-CM', 'GENDER_DYSPHORIA', 'Exclusion', 'ALL', 40, 74, NULL, NULL),
        ('F64.2', 'ICD10-CM', 'GENDER_DYSPHORIA', 'Exclusion', 'ALL', 40, 74, NULL, NULL),
        ('F64.8', 'ICD10-CM', 'GENDER_DYSPHORIA', 'Exclusion', 'ALL', 40, 74, NULL, NULL),
        ('F64.9', 'ICD10-CM', 'GENDER_DYSPHORIA', 'Exclusion', 'ALL', 40, 74, NULL, NULL),
        ('Z87.890', 'ICD10-CM', 'GENDER_DYSPHORIA_HISTORY', 'Exclusion', 'ALL', 40, 74, NULL, NULL),
        ('50', 'MODIFIER', 'BILATERAL_MODIFIER', 'Exclusion', 'F', 40, 74, NULL, NULL),
        ('Z51.5', 'ICD10-CM', 'PALLIATIVE_CARE_ENCOUNTER', 'Exclusion', 'ALL', 40, 74, NULL, NULL),

        -- Demographics (CDC Race & Ethnicity)
        ('1002-5', 'CDC', 'AMERICAN_INDIAN_OR_ALASKA_NATIVE', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2028-9', 'CDC', 'ASIAN', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2054-5', 'CDC', 'BLACK_OR_AFRICAN_AMERICAN', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2076-8', 'CDC', 'NATIVE_HAWAIIAN_OR_PACIFIC_ISLANDER', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2106-3', 'CDC', 'WHITE', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2135-2', 'CDC', 'HISPANIC_OR_LATINO', 'Demographics', 'ALL', 40, 74, NULL, NULL),
        ('2186-5', 'CDC', 'NOT_HISPANIC_OR_LATINO', 'Demographics', 'ALL', 40, 74, NULL, NULL)
) AS bcs(code, system, codeDisplay, topicCategory, subjectAdministrativeGender, subjectAgeMin, subjectAgeMax, effectivePeriodStart, effectivePeriodEnd);


-- -----------------------------------------------------------------------------
-- MEASURE: Well-Child Visits (WCV / W15 / W30 / W34)
-- -----------------------------------------------------------------------------
INSERT INTO claimspan.bronze.measure_library
SELECT 
    'hedis' AS measureSource,
    code,
    system,
    'WCV' AS measureIdentifier,
    'Well-Child Visits' AS measureTitle,
    codeDisplay,
    'Preventive Care' AS topicCategory,
    'ALL' AS subjectAdministrativeGender,
    subjectAgeMin,
    subjectAgeMax,
    CAST('2025-01-01' AS DATE) AS effectivePeriodStart,
    CAST('2026-12-31' AS DATE) AS effectivePeriodEnd
FROM (
    VALUES
        -- CPT Well-Child Preventive Visits (0–17 years)
        ('99381', 'CPT', 'WELL_CHILD_VISIT_NEW_INFANT', 0, 0),
        ('99382', 'CPT', 'WELL_CHILD_VISIT_NEW_EARLY_CHILDHOOD', 1, 4),
        ('99383', 'CPT', 'WELL_CHILD_VISIT_NEW_LATE_CHILDHOOD', 5, 11),
        ('99384', 'CPT', 'WELL_CHILD_VISIT_NEW_ADOLESCENT', 12, 17),
        ('99391', 'CPT', 'WELL_CHILD_VISIT_EST_INFANT', 0, 0),
        ('99392', 'CPT', 'WELL_CHILD_VISIT_EST_EARLY_CHILDHOOD', 1, 4),
        ('99393', 'CPT', 'WELL_CHILD_VISIT_EST_LATE_CHILDHOOD', 5, 11),
        ('99394', 'CPT', 'WELL_CHILD_VISIT_EST_ADOLESCENT', 12, 17),

        -- HCPCS
        ('G0438', 'HCPCS', 'ANNUAL_WELLNESS_VISIT_FIRST', 0, 17),
        ('G0439', 'HCPCS', 'ANNUAL_WELLNESS_VISIT_SUBSEQUENT', 0, 17),

        -- ICD-10-CM Routine Examination Diagnoses
        ('Z00.110', 'ICD10-CM', 'HEALTH_CHECK_HEALTHY_INFANT', 0, 0),
        ('Z00.111', 'ICD10-CM', 'HEALTH_CHECK_INFANT_UNDER_29_DAYS', 0, 0),
        ('Z00.121', 'ICD10-CM', 'WELL_CHILD_EXAM_WITH_ABNORMAL_FINDINGS', 0, 17),
        ('Z00.129', 'ICD10-CM', 'WELL_CHILD_EXAM_WITHOUT_ABNORMAL_FINDINGS', 0, 17),
        ('Z00.00', 'ICD10-CM', 'GENERAL_ADULT_EXAM_WITHOUT_ABNORMAL_FINDINGS', 12, 17),
        ('Z00.01', 'ICD10-CM', 'GENERAL_ADULT_EXAM_WITH_ABNORMAL_FINDINGS', 12, 17),

        -- SNOMED CT Clinical Findings / Procedures
        ('410620009', 'SNOMED', 'WELL_CHILD_VISIT', 0, 17),
        ('170258001', 'SNOMED', 'CHILD_HEALTH_SURVEILLANCE', 0, 17),
        ('170260004', 'SNOMED', 'CHILD_HEALTH_SURVEILLANCE_EXAM', 0, 17)
) AS wcv(code, system, codeDisplay, subjectAgeMin, subjectAgeMax);

-- -----------------------------------------------------------------------------
-- MEASURE: Documented Assessment After Mammogram
-- -----------------------------------------------------------------------------
INSERT INTO claimspan.bronze.measure_library
SELECT 
    'hedis' AS measureSource,
    code,
    system,
    'BCS-E' AS measureIdentifier,
    'Documented Assessment After Mammogram' AS measureTitle,
    codeDisplay,
    topicCategory,
    subjectAdministrativeGender,
    subjectAgeMin,
    subjectAgeMax,
    CAST(effectivePeriodStart AS DATE) AS effectivePeriodStart,
    CAST(effectivePeriodEnd AS DATE) AS effectivePeriodEnd
FROM (
    VALUES
        -- CPT (Mammography)
        ('77061', 'CPT', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),
        ('77062', 'CPT', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),

        -- RadLex (BI-RADS Assessment)
        ('RID36028', 'RADLEX', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),
        ('RID36029', 'RADLEX', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),

        -- SNOMED (BI-RADS Assessment)
        ('397138000', 'SNOMED', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),
        ('397140005', 'SNOMED', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),

        -- LOINC (Mammography)
        ('24604-1', 'LOINC', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31'),
        ('24605-8', 'LOINC', 'DOCUMENTED_ASSESSMENT_AFTER_MAMMOGRAM', 'Documented Assessment After Mammogram', 'F', 40, 74, '2026-01-01', '2026-12-31')
) AS bcs_assessment(code, system, codeDisplay, topicCategory, subjectAdministrativeGender, subjectAgeMin, subjectAgeMax, effectivePeriodStart, effectivePeriodEnd);


SELECT * FROM claimspan.bronze.measure_library;
