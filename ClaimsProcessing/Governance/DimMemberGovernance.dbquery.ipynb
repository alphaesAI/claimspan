-- %%
-- Step 1: Grant visibility to the catalog and schema
GRANT USE CATALOG ON CATALOG claimspan TO `saythu000@gmail.com`;
GRANT USE SCHEMA ON SCHEMA claimspan.gold TO `saythu000@gmail.com`;

-- Step 2: Grant access to a specific table (or ALL tables)
GRANT SELECT ON TABLE claimspan.gold.gold_dimmember TO `saythu000@gmail.com`;
