# %%
for file in dbutils.fs.ls("/Workspace/Repos/logi@openhealthagents.org/claimspan/ClaimsProcessing/source/834/processed"):
    if file.path.endswith(".txt"):
        dbutils.fs.cp(file.path, f"/Volumes/claimspan/source/834/{file.name}"); dbutils.fs.rm(file.path)

# %%
# %sql
CREATE RECIPIENT saythusurya
COMMENT "adding saythu surya as a recipient";

# %%
# %sql
DROP TABLE claimspan.bronzedlt.silver_memberpersonbridge;
