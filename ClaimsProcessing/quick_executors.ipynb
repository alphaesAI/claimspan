# %%
for file in dbutils.fs.ls("/Workspace/Repos/logi@openhealthagents.org/claimspan/ClaimsProcessing/source/834/processed"):
    if file.path.endswith(".txt"):
        dbutils.fs.cp(file.path, f"/Volumes/claimspan/source/834/{file.name}"); dbutils.fs.rm(file.path)

# %%
# %sql
CREATE RECIPIENT saythusurya
COMMENT "adding saythu surya as a recipient";

# %%
# %sql
DROP TABLE claimspan.bronzedlt.silver_memberpersonbridge;

# %%
# %sql
SELECT * FROM claimspan.bronzedlt.edi_parsed_mapped;

# %%
# %sql
SELECT * FROM claimspan.bronzedlt.bronze_837_claims_exploded;

# %%
# %sql
SELECT * FROM event_log("eb0e61e1-95cd-4163-85b5-9f56db60108c") ORDER BY timestamp DESC;

# %%
# %sql
SELECT 
  timestamp,
  message,
  details:flow_progress:metrics:num_output_rows AS output_rows
FROM event_log("eb0e61e1-95cd-4163-85b5-9f56db60108c")
WHERE level = "ERROR"
ORDER BY timestamp DESC;

# %%
# %sql
SELECT * FROM claimspan.bronzedlt.caregapreport;

# %%
# %sql
DESCRIBE claimspan.bronzedlt.gold_dimmember;

# %%
# %sql
SELECT * FROM claimspan.bronzedlt.silver_gapsincare;

# %%
# %sql
SELECT DISTINCT * FROM claimspan.bronzedlt.silver_gapsincare;
